# %%
# Basic import
import warnings
warnings.filterwarnings('ignore')

from country_code_file import country_codes
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
# %matplotlib inline

# %% [markdown]
# # Overview
# > The goal of this project is to provide a detailed EDA representation of the total number of users per attributes specified. With this project I will break this into sections to ananlyse as much of the dataset.
#
# - Workflow:
#     - `Basic Discovery`
#     - `Filtering`
#     - `Categorical features` EDA
#     - `Numerical features` EDA
#
# - toc: true
# - badges: true
# - comments: true
# - categories: [EDA, Pandas]
# - image: https://duckduckgo.com/?q=data+science+image&atb=v314-1&iax=images&ia=images&iai=https%3A%2F%2Fnews.southernct.edu%2Fwp-content%2Fuploads%2F2019%2F12%2FDataScience_home.jpg

# %%
df = pd.read_csv('./Users_Descriptives.csv')
df.columns = df.columns.str.replace("[^\w\s]", "").str.replace(" ", "_").str.lower()
df.head()
# Out:
#        id        city               state        country gender  \
# 0   38940   Bydgoszcz  Kujawsko-Pomorskie         Poland   male
# 1  168107  Marysville                Ohio  United States   male
# 2  168124    Chaville       Île-de-France         France   male
# 3      13     Raleigh      North Carolina  United States   male
# 4  168141      Denver            Colorado  United States   male
#
#    profile_length  activitymonthlyduration  highagreement  lowagreement  \
# 0            44.0                    12.53          387.0          68.0
# 1             4.0                     9.80           77.0           3.0
# 2             3.0                    10.53           55.0           2.0
# 3           179.0                    12.79         5212.0         210.0
# 4             1.0                     1.72            0.0           0.0
#
#      views      fame  questions  answers  comments   edits  tokens
# 0   2641.0   24175.0      302.0     52.0     479.0  1046.0   422.0
# 1    153.0    1089.0        1.0     32.0      84.0    40.0    23.0
# 2     52.0     743.0       12.0      6.0      10.0    44.0    23.0
# 3  42264.0  206112.0       10.0   2134.0    3870.0  3842.0   832.0
# 4     19.0     123.0        4.0      NaN       2.0    12.0     7.0

# %% [markdown]
# ## Basic Discovery
# - In this part of the notebook will just go through getting to know what data we are dealing with before doing in sort of cleaning and plotting.

# %%
df.shape
# Out:
# (27030, 16)

# %% [markdown]
# **Conclusion**
# - We have `3,747,583` rows of data. Since this has a huge quantity let's check out how much `memory` this data is using.
# - We see that the machine uses `1,24GB` of memory.

# %%
(df
 .memory_usage(deep=True)
 .sum()
)
# Out:
# 9134560

# %%
df.describe().transpose()
# Out:
#                            count           mean            std  min       25%  \
# id                       27030.0  191818.114539  138829.807954  1.0  53481.25
# profile_length           25576.0      14.467000      30.570125  1.0      1.00
# activitymonthlyduration  27029.0       9.411596       3.691719  0.0      8.36
# highagreement            27029.0     340.932406    1056.045476  0.0      8.00
# lowagreement             27029.0      40.218876     802.867348  0.0      0.00
# views                    27029.0     595.706981    5068.626517  0.0     33.00
# fame                     27029.0    5932.136890   23795.705914  1.0    169.00
# questions                22593.0      22.046430      54.278724  1.0      2.00
# answers                  24374.0      78.133380     394.072590  1.0      4.00
# comments                 23574.0     157.224782     992.129030  1.0      7.00
# edits                    26481.0     212.108908    1224.032594  1.0     13.00
# tokens                   26679.0      55.946325     120.938858  1.0      9.00
#
#                                50%        75%         max
# id                       179061.00  297972.00   432130.00
# profile_length                3.00      15.00     1111.00
# activitymonthlyduration      10.98      11.84       12.84
# highagreement                60.00     272.00    60260.00
# lowagreement                  1.00       8.00    94846.00
# views                       109.00     341.00   585755.00
# fame                        925.00    3728.00  1042979.00
# questions                     7.00      21.00     2539.00
# answers                      14.00      47.00    25827.00
# comments                     23.00      81.00    50468.00
# edits                        43.00     142.00   113788.00
# tokens                       27.00      62.00     8367.00

# %%
df.dtypes
# Out:
# id                           int64
# city                        object
# state                       object
# country                     object
# gender                      object
# profile_length             float64
# activitymonthlyduration    float64
# highagreement              float64
# lowagreement               float64
# views                      float64
# fame                       float64
# questions                  float64
# answers                    float64
# comments                   float64
# edits                      float64
# tokens                     float64
# dtype: object

# %%
# Function
def missing_data(data):
    """
    This function calculates missing data for each column in a pandas dataframe.
    It returns a pandas dataframe containing the column name, the number of missing values,
    the percentage of missing values, the data type of the column, and the set of unique values
    for that column.
    
    :param data: A pandas dataframe
    :return: A pandas dataframe
    """
    total = data.isnull().sum()
    percent = round(data.isnull().sum()/data.isnull().count()*100,2)
    tt = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
    types = []
    for col in data.columns:
        dtype = str(data[col].dtype)
        types.append(dtype)
    tt['Types'] = types
    return(np.transpose(tt))

def unique_values(data):
    """
    This function takes a pandas dataframe as input and returns a transposed
    pandas dataframe that lists the total number of observations and the number
    of unique values for each column.
    
    Parameters:
    -----------
    data: A pandas dataframe.
    
    Returns:
    --------
    A transposed pandas dataframe that lists the total number of observations
    and the number of unique values for each column.
    """
    total = data.count()
    tt = pd.DataFrame(total)
    tt.columns = ['Total']
    uniques = []
    for col in data.columns:
        unique = data[col].nunique()
        uniques.append(unique)
    tt['Uniques'] = uniques
    return(np.transpose(tt))

# %%
obj = df.select_dtypes(include="object")
missing_data(obj)
# Out:
#            city   state country  gender
# Total      8227    7134       2       1
# Percent   30.44   26.39    0.01     0.0
# Types    object  object  object  object

# %%
num = df.select_dtypes(include="number")
nm = missing_data(num)
nm.transpose()
# Out:
#                         Total Percent    Types
# id                          0     0.0    int64
# profile_length           1454    5.38  float64
# activitymonthlyduration     1     0.0  float64
# highagreement               1     0.0  float64
# lowagreement                1     0.0  float64
# views                       1     0.0  float64
# fame                        1     0.0  float64
# questions                4437   16.42  float64
# answers                  2656    9.83  float64
# comments                 3456   12.79  float64
# edits                     549    2.03  float64
# tokens                    351     1.3  float64

# %% [markdown]
# **Conclusion**
# - The `city` column contains has the highest number of missing values with 31%
# - But since all the categorical columns have low percentages we can just drop them

# %%
nan_df = df[df.isna().any(axis=1)]
nan_df
# Out:
#            id         city      state        country  gender  profile_length  \
# 4      168141       Denver   Colorado  United States    male             1.0
# 6      227169          NaN        NaN       Viet Nam    male             1.0
# 7      103814          NaN    Arizona  United States    male             1.0
# 8      168177          NaN        NaN       Portugal    male             3.0
# 9          30          NaN        NaN  United States    male             8.0
# ...       ...          ...        ...            ...     ...             ...
# 27020   63928  Minneapolis  Minnesota  United States  female             9.0
# 27023   63985       Dublin   Leinster        Ireland    male             3.0
# 27025  128654          NaN        NaN         Norway    male             6.0
# 27026  128661          NaN        NaN        Germany    male             8.0
# 27029  373569      Atlanta     Georgi            NaN     NaN             NaN
#
#        activitymonthlyduration  highagreement  lowagreement   views     fame  \
# 4                         1.72            0.0           0.0    19.0    123.0
# 6                         6.01            0.0           0.0    16.0     75.0
# 7                        10.85          136.0           1.0   153.0   2212.0
# 8                        11.75         1218.0          72.0  1508.0   9912.0
# 9                        12.83          146.0           8.0  1522.0  11427.0
# ...                        ...            ...           ...     ...      ...
# 27020                     0.10            0.0           0.0    35.0     31.0
# 27023                    12.68           82.0           8.0   136.0   1273.0
# 27025                    11.93          104.0           2.0   149.0   1772.0
# 27026                    11.49          241.0           7.0   507.0   3827.0
# 27029                      NaN            NaN           NaN     NaN      NaN
#
#        questions  answers  comments  edits  tokens
# 4            4.0      NaN       2.0   12.0     7.0
# 6            3.0      NaN       2.0   10.0     8.0
# 7           18.0     17.0      57.0   90.0    65.0
# 8           95.0    219.0     848.0  638.0   170.0
# 9           11.0     65.0      65.0  153.0    99.0
# ...          ...      ...       ...    ...     ...
# 27020        NaN      NaN       NaN    NaN     2.0
# 27023        NaN     29.0       8.0   29.0    18.0
# 27025        9.0      7.0      31.0   50.0    37.0
# 27026        2.0     47.0      79.0  102.0    59.0
# 27029        NaN      NaN       NaN    NaN     NaN
#
# [14073 rows x 16 columns]

# %%
def clean(data):
    # Categorical
    cols = ['city', 'state', 'country', 'gender']
    for objs in cols:
        data = data.dropna(subset=cols)
        
    # Numerical
    numerical = data.select_dtypes(include="number")
    for num in numerical.columns:
        data[num].fillna(data[num].median(), inplace=True)
#         data[num].fillna(0, inplace=True)
    
    data["city"] = data['city'].astype('category')
    data["state"] = data['state'].astype('category')
    data["country"] = data['country'].astype('category')
    data["gender"] = data['gender'].astype('category')
    return data

# %%
user_d = clean(df)
md = missing_data(user_d)
md.transpose()
# Out:
#                         Total Percent     Types
# id                          0     0.0     int64
# city                        0     0.0  category
# state                       0     0.0  category
# country                     0     0.0  category
# gender                      0     0.0  category
# profile_length              0     0.0   float64
# activitymonthlyduration     0     0.0   float64
# highagreement               0     0.0   float64
# lowagreement                0     0.0   float64
# views                       0     0.0   float64
# fame                        0     0.0   float64
# questions                   0     0.0   float64
# answers                     0     0.0   float64
# comments                    0     0.0   float64
# edits                       0     0.0   float64
# tokens                      0     0.0   float64

# %% [markdown]
# ## Filtering
# **QUESTIONS**
# - What is the average and sum of variables by gender.
# - What is the average and sum of variables by country.
# - Which gender per country as the most views, fame, questions

# %%
# Average and sum of variables by gender.
(user_d
 .groupby("gender")
 .agg({"questions": ["mean", "sum"],
       "answers": ["mean", "sum"],
       "comments": ["mean", "sum"],
       "activitymonthlyduration": ["mean", "sum"]
      })
)
# Out:
#         questions              answers               comments             \
#              mean       sum       mean        sum        mean        sum
# gender
# female  18.073489   33201.0  58.049537   106637.0  114.124115   209646.0
# male    19.156781  312313.0  72.173894  1176651.0  137.562964  2242689.0
#
#        activitymonthlyduration
#                           mean        sum
# gender
# female                9.108519   16732.35
# male                  9.634311  157068.17

# %% [markdown]
# **Conclusion**
# - Clearly males are the ones with the highest average and sum
# - Let's see which country reflects this

# %%
# Average and sum of variables by country.
user_d = user_d.replace({'United States':'US', 'United Kingdom':'UK', 'South Africa':'SA'})
user_country_code = user_d[user_d["country"].isin(["US", "UK", "India", "Germany", "SA",
                                                   "Canada", "Australia", "France"])]
(user_country_code
 .groupby("country")
 .agg({"questions": ["mean", "sum"],
       "answers": ["mean", "sum"],
       "views": ["mean", "sum"],
       "fame": ["mean", "sum"]
      })
)
# Out:
#            questions               answers                 views             \
#                 mean       sum        mean       sum        mean        sum
# country
# Australia  19.497976   14448.0   78.476383   58151.0  521.676113   386562.0
# Canada     19.007619   19958.0   59.100952   62056.0  430.753333   452291.0
# France     17.044728    5335.0   72.610224   22727.0  471.498403   147579.0
# Germany    20.676152   15259.0  115.822493   85477.0  830.651762   613021.0
# India      22.000000   20460.0   39.550538   36782.0  322.197849   299644.0
# SA         15.066667    1356.0   33.677778    3031.0  319.933333    28794.0
# UK         22.278204   37717.0  105.061429  177869.0  704.119905  1192075.0
# US         18.188064  147196.0   68.508093  554436.0  672.393674  5441682.0
#
#                   fame
#                   mean         sum
# country
# Australia  5563.132254   4122281.0
# Canada     5443.321905   5715488.0
# France     5257.386581   1645562.0
# Germany    9568.598916   7061626.0
# India      3317.529032   3085302.0
# SA         2660.055556    239405.0
# UK         7853.476669  13295936.0
# US         5980.821945  48402792.0

# %% [markdown]
# **Conclusion**
# - The `UK` reflects the highest average and sum
# - `Germany` follows in second

# %%
# Gender per country with views
user_group = user_d[user_d["country"].isin(["US", "UK", "India", "Germany", "SA",
                                           "Canada", "Australia", "France"])]
(user_group
   .groupby(['gender','country'])
   .views
   .first()
   .unstack()
)
# Out:
# country  Australia  Canada  France  Germany  India      SA     UK      US
# gender
# female       122.0   180.0    34.0    114.0    9.0  1124.0   59.0  1141.0
# male         293.0   267.0    52.0     93.0  162.0   227.0  897.0   153.0

# %%
# gender per country with fame
user_d = user_d.replace({'United States':'US', 'United Kingdom':'UK', 'South Africa':'SA'})
user_group = user_d[user_d["country"].isin(["US", "UK", "India", "Germany", "SA",
                                           "Canada", "Australia", "France"])]
(user_group
   .groupby(['gender','country'])
   .fame
   .first()
   .unstack()
)
# Out:
# country  Australia  Canada  France  Germany  India       SA       UK      US
# gender
# female      1255.0  6028.0   271.0   1314.0   13.0  12127.0     29.0  3189.0
# male        4439.0  1450.0   743.0    738.0  621.0   2135.0  11213.0  1089.0

# %%
# gender per country with questions
user_d = user_d.replace({'United States':'US', 'United Kingdom':'UK', 'South Africa':'SA'})
user_group = user_d[user_d["country"].isin(["US", "UK", "India", "Germany", "SA",
                                           "Canada", "Australia", "France"])]
(user_group
   .groupby(['gender','country'])
   .questions
   .first()
   .unstack()
)
# Out:
# country  Australia  Canada  France  Germany  India     SA     UK    US
# gender
# female         6.0     3.0     7.0     29.0    2.0  105.0    6.0  17.0
# male          26.0    17.0    12.0      5.0    6.0    7.0  133.0   1.0

# %% [markdown]
# ## EDA  Analysis

# %% [markdown]
# ### Categorical
# **QUESTIONS**
# - What is the top countries with high fame by gender?
# - What is the top cities with high questions?
# - What is the total fame by country?
# - `World Map`: Total questions, answers, edits, monthly duration by country

# %%
pie_gender_views = (user_d
 .groupby('gender', as_index=False)
 .sum()
 .sort_values(by='views', ascending=False)
)
def pie_chart(data, col, val):
    fig = px.pie(data, values=val, names=col,
            color_discrete_sequence=['#14213d', '#9d0208'],
            title=f'Total {val} by {col}',
            hole=.6)
    fig.update_traces(textposition='inside', textinfo='percent+label')
    fig.layout.template = 'plotly_dark'
    return fig.show()
pie_chart(pie_gender_views, 'gender', 'views')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="146df534-b190-46f8-a241-e94611433f4e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("146df534-b190-46f8-a241-e94611433f4e")) {                    Plotly.newPlot(                        "146df534-b190-46f8-a241-e94611433f4e",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.6,"hovertemplate":"gender=%{label}<br>views=%{value}<extra></extra>","labels":["male","female"],"legendgroup":"","name":"","showlegend":true,"values":[10118866.0,870199.0],"type":"pie","textinfo":"percent+label","textposition":"inside"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet ...

# %%
# Histogram Gender
gender_hist = user_d.replace('male', 'Males').replace('female', 'Females')
for gen in gender_hist['gender'].unique():
    dataframe = gender_hist.loc[gender_hist['gender'] == gen].groupby('country')['fame'].agg('sum').sort_values(ascending=False)[:10]
    dataframe = pd.DataFrame({'Country':dataframe.index, 'Fame':dataframe.values})
    fig = px.histogram(dataframe, x="Fame", y='Country', color='Country',
                       title=f'Top 10 countries with fame by {gen}')
    fig.layout.template = 'plotly_dark'
    fig.update_traces(opacity=0.7)
    fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ff87ffbf-bb4b-443c-8526-fd66a341cebe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ff87ffbf-bb4b-443c-8526-fd66a341cebe")) {                    Plotly.newPlot(                        "ff87ffbf-bb4b-443c-8526-fd66a341cebe",                        [{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"Country=%{y}<br>sum of Fame=%{x}<extra></extra>","legendgroup":"US","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"US","offsetgroup":"US","orientation":"h","showlegend":true,"x":[44086389.0],"xaxis":"x","y":["US"],"yaxis":"y","type":"histogram","opacity":0.7},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"Country=%{y}<br>sum of Fame=%{x}<extra></extra>","legendgroup":"UK","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"UK","offsetgroup":"UK","orientation":"h","showlegend":true,"x":[12437044.0],"xaxis":"x","y":["UK"],"yaxis":"y","type":"histogram","opacity":0.7},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"Country=%{y}<br>sum of Fame=%{x}<extra></extra>","legendgroup":"Germany","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Germany","offsetgroup":"Germany","orientation":"h","showlegend":true,"x":[6617659.0],"xaxis":"x","y":["Germany"],"yaxis":"y","type":"histogram","opacity":0.7},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"Country=%{y}<br>sum of Fame=%{x}<extra></extra>","legendgroup":"Canada","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Canada","offsetgroup":"Canada","orientation":"h","showlegend":true,"x":[5279992.0],"xaxis":"x","y":["Canada"],"yaxis":"y","type":"histogram","opacity":0.7},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"Country=%{y}<br>sum of Fame=%{x}<extra></extra>","legendgroup":"Australia","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Australia","offsetgroup":"Australia","orientation":"h","showlegend":true,"x":[3841664.0],"xaxis":"x","y":["Australia"],"yaxis":"y","type":"histogram","opacity":0.7},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"Country=%{y}<br>sum of Fame=%{x}<extra></extra>","legendgroup":"India","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"India","offsetgroup":"India","orientation":"h","showlegend":true,"x":[2684128.0],"xaxis":"x","y":["India"],"yaxis":"y","type":"histogram","opacity":0.7},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"Country=%{y}<br>sum of Fame=%{x}<extra></extra>","legendgroup":"France","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"France","offsetgroup":"France","orientation":"h","showlegend":true,"x":[1545094.0],"xaxis":"x","y":["France"],"yaxis":"y","type":"histogram","opacity":0.7},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"Country=%{y}<br>sum of Fame=%{x}<extra></extra>","legendgroup":"Netherlands","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Netherlands","offsetgroup":"Netherlands","orientation":"h","showlegend":true,"x":[1540423.0],"xaxis":"x","y":["Netherlands"],"yaxis":"y","type":"histogram","opacity":0.7},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"Country=%{y}<br>sum of Fame=%{x}<extra></extra>","legendgroup":"Sweden","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Sweden","offsetgroup":"Sweden","orientation":"h","showlegend":true,"x":[1540153.0],"xaxis":"x","y":["Sweden"],"yaxis":"y","type":"histogram","opacity":0.7},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"Country=%{y}<br>sum of Fame=%{x}<extra></extra>","legendgroup":"Singapore","marker":{"color":"#FECB52","pattern":{"shap ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="38a0981f-c58b-47ad-af47-3c5d888ec5ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("38a0981f-c58b-47ad-af47-3c5d888ec5ec")) {                    Plotly.newPlot(                        "38a0981f-c58b-47ad-af47-3c5d888ec5ec",                        [{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"Country=%{y}<br>sum of Fame=%{x}<extra></extra>","legendgroup":"US","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"US","offsetgroup":"US","orientation":"h","showlegend":true,"x":[4316403.0],"xaxis":"x","y":["US"],"yaxis":"y","type":"histogram","opacity":0.7},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"Country=%{y}<br>sum of Fame=%{x}<extra></extra>","legendgroup":"UK","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"UK","offsetgroup":"UK","orientation":"h","showlegend":true,"x":[858892.0],"xaxis":"x","y":["UK"],"yaxis":"y","type":"histogram","opacity":0.7},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"Country=%{y}<br>sum of Fame=%{x}<extra></extra>","legendgroup":"Germany","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Germany","offsetgroup":"Germany","orientation":"h","showlegend":true,"x":[443967.0],"xaxis":"x","y":["Germany"],"yaxis":"y","type":"histogram","opacity":0.7},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"Country=%{y}<br>sum of Fame=%{x}<extra></extra>","legendgroup":"Canada","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Canada","offsetgroup":"Canada","orientation":"h","showlegend":true,"x":[435496.0],"xaxis":"x","y":["Canada"],"yaxis":"y","type":"histogram","opacity":0.7},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"Country=%{y}<br>sum of Fame=%{x}<extra></extra>","legendgroup":"India","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"India","offsetgroup":"India","orientation":"h","showlegend":true,"x":[401174.0],"xaxis":"x","y":["India"],"yaxis":"y","type":"histogram","opacity":0.7},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"Country=%{y}<br>sum of Fame=%{x}<extra></extra>","legendgroup":"Australia","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Australia","offsetgroup":"Australia","orientation":"h","showlegend":true,"x":[280617.0],"xaxis":"x","y":["Australia"],"yaxis":"y","type":"histogram","opacity":0.7},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"Country=%{y}<br>sum of Fame=%{x}<extra></extra>","legendgroup":"Sweden","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Sweden","offsetgroup":"Sweden","orientation":"h","showlegend":true,"x":[168209.0],"xaxis":"x","y":["Sweden"],"yaxis":"y","type":"histogram","opacity":0.7},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"Country=%{y}<br>sum of Fame=%{x}<extra></extra>","legendgroup":"Croatia","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Croatia","offsetgroup":"Croatia","orientation":"h","showlegend":true,"x":[164729.0],"xaxis":"x","y":["Croatia"],"yaxis":"y","type":"histogram","opacity":0.7},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"Country=%{y}<br>sum of Fame=%{x}<extra></extra>","legendgroup":"Netherlands","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Netherlands","offsetgroup":"Netherlands","orientation":"h","showlegend":true,"x":[145687.0],"xaxis":"x","y":["Netherlands"],"yaxis":"y","type":"histogram","opacity":0.7},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"Country=%{y}<br>sum of Fame=%{x}<extra></extra>","legendgroup":"Norway","marker":{"color":"#FECB52","pattern":{"shape":""}}," ...

# %% [markdown]
# **Coclusion**
# - For `males`: US as expected came first but interestingly we have `UK second`. We can get a closer look at which city in the UK carry most of fame.
# - For `females`: US again first, but `India came in second` we is the opposite of the males. We will also look at which city in India carry the most fame.

# %%
india_female_city = user_d[(user_d['gender']=='female') & (user_d['country']=='India')]
(india_female_city['city']
 .value_counts()
 .reset_index()
 .rename(columns={'index':'city', 'city':'count'})[:7]
)
# Out:
#         city  count
# 0  Bengaluru     34
# 1    Chennai     19
# 2     Mumbai     15
# 3  Hyderabad     11
# 4       Pune      9
# 5  Ahmedabad      7
# 6      Kochi      3

# %%
uk_male_city = user_d[(user_d['gender']=='male') & (user_d['country']=='UK')]
(uk_male_city['city']
 .value_counts()
 .reset_index()
 .rename(columns={'index':'city', 'city':'count'})[:7]
)
# Out:
#          city  count
# 0      London    734
# 1   Cambridge     57
# 2  Manchester     47
# 3   Edinburgh     45
# 4     Bristol     42
# 5     Glasgow     35
# 6      Oxford     32

# %%
# Histogram Countries
dataframe = user_d.groupby('state').agg('sum').sort_values(by='views', ascending=False)[:10]
fig = px.histogram(dataframe, x="views", y=dataframe.index, color=dataframe.index,
                   title=f'Top 10 states with high views')
fig.layout.template = 'plotly_dark'
fig.update_traces(opacity=0.7)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="205fb190-bf52-4fcc-953c-be548fb6c167" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("205fb190-bf52-4fcc-953c-be548fb6c167")) {                    Plotly.newPlot(                        "205fb190-bf52-4fcc-953c-be548fb6c167",                        [{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"state=%{y}<br>sum of views=%{x}<extra></extra>","legendgroup":"California","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"California","offsetgroup":"California","orientation":"h","showlegend":true,"x":[1579430.0],"xaxis":"x","y":["California"],"yaxis":"y","type":"histogram","opacity":0.7},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"state=%{y}<br>sum of views=%{x}<extra></extra>","legendgroup":"England","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"England","offsetgroup":"England","orientation":"h","showlegend":true,"x":[1060875.0],"xaxis":"x","y":["England"],"yaxis":"y","type":"histogram","opacity":0.7},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"state=%{y}<br>sum of views=%{x}<extra></extra>","legendgroup":"New York","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"New York","offsetgroup":"New York","orientation":"h","showlegend":true,"x":[675276.0],"xaxis":"x","y":["New York"],"yaxis":"y","type":"histogram","opacity":0.7},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"state=%{y}<br>sum of views=%{x}<extra></extra>","legendgroup":"Washington","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Washington","offsetgroup":"Washington","orientation":"h","showlegend":true,"x":[451039.0],"xaxis":"x","y":["Washington"],"yaxis":"y","type":"histogram","opacity":0.7},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"state=%{y}<br>sum of views=%{x}<extra></extra>","legendgroup":"North Carolina","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"North Carolina","offsetgroup":"North Carolina","orientation":"h","showlegend":true,"x":[434269.0],"xaxis":"x","y":["North Carolina"],"yaxis":"y","type":"histogram","opacity":0.7},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"state=%{y}<br>sum of views=%{x}<extra></extra>","legendgroup":"Texas","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Texas","offsetgroup":"Texas","orientation":"h","showlegend":true,"x":[320859.0],"xaxis":"x","y":["Texas"],"yaxis":"y","type":"histogram","opacity":0.7},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"state=%{y}<br>sum of views=%{x}<extra></extra>","legendgroup":"Berlin","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Berlin","offsetgroup":"Berlin","orientation":"h","showlegend":true,"x":[250786.0],"xaxis":"x","y":["Berlin"],"yaxis":"y","type":"histogram","opacity":0.7},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"state=%{y}<br>sum of views=%{x}<extra></extra>","legendgroup":"Ontario","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Ontario","offsetgroup":"Ontario","orientation":"h","showlegend":true,"x":[208528.0],"xaxis":"x","y":["Ontario"],"yaxis":"y","type":"histogram","opacity":0.7},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"state=%{y}<br>sum of views=%{x}<extra></extra>","legendgroup":"Massachusetts","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Massachusetts","offsetgroup":"Massachusetts","orientation":"h","showlegend":true,"x":[197858.0],"xaxis":"x","y":["Massachusetts"],"yaxis":"y","type":"histogram","opacity":0.7},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"state=%{y}<br>sum of views=%{x}<e ...

# %%
# Histogram Cities
unq_variant = user_d[user_d["country"].isin(["US", "UK", "India", "Germany"])]
dataframe = unq_variant.groupby('city').agg('sum').sort_values(by='questions', ascending=False)[:10]
fig = px.histogram(dataframe, x="questions", y=dataframe.index, color=dataframe.index,
                   title=f'Top 10 cities with high questions',
                   labels={'sum of questions':'questions'})
fig.layout.template = 'plotly_dark'
fig.update_traces(opacity=0.7)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e86cf0fe-90f7-4297-a979-4b157fa4b6c7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e86cf0fe-90f7-4297-a979-4b157fa4b6c7")) {                    Plotly.newPlot(                        "e86cf0fe-90f7-4297-a979-4b157fa4b6c7",                        [{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"city=%{y}<br>sum of questions=%{x}<extra></extra>","legendgroup":"London","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"London","offsetgroup":"London","orientation":"h","showlegend":true,"x":[16991.0],"xaxis":"x","y":["London"],"yaxis":"y","type":"histogram","opacity":0.7},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"city=%{y}<br>sum of questions=%{x}<extra></extra>","legendgroup":"San Francisco","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"San Francisco","offsetgroup":"San Francisco","orientation":"h","showlegend":true,"x":[11654.0],"xaxis":"x","y":["San Francisco"],"yaxis":"y","type":"histogram","opacity":0.7},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"city=%{y}<br>sum of questions=%{x}<extra></extra>","legendgroup":"New York","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"New York","offsetgroup":"New York","orientation":"h","showlegend":true,"x":[10504.0],"xaxis":"x","y":["New York"],"yaxis":"y","type":"histogram","opacity":0.7},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"city=%{y}<br>sum of questions=%{x}<extra></extra>","legendgroup":"Bengaluru","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Bengaluru","offsetgroup":"Bengaluru","orientation":"h","showlegend":true,"x":[5999.0],"xaxis":"x","y":["Bengaluru"],"yaxis":"y","type":"histogram","opacity":0.7},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"city=%{y}<br>sum of questions=%{x}<extra></extra>","legendgroup":"Seattle","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Seattle","offsetgroup":"Seattle","orientation":"h","showlegend":true,"x":[5951.0],"xaxis":"x","y":["Seattle"],"yaxis":"y","type":"histogram","opacity":0.7},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"city=%{y}<br>sum of questions=%{x}<extra></extra>","legendgroup":"Berlin","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Berlin","offsetgroup":"Berlin","orientation":"h","showlegend":true,"x":[5585.0],"xaxis":"x","y":["Berlin"],"yaxis":"y","type":"histogram","opacity":0.7},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"city=%{y}<br>sum of questions=%{x}<extra></extra>","legendgroup":"Los Angeles","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Los Angeles","offsetgroup":"Los Angeles","orientation":"h","showlegend":true,"x":[5087.0],"xaxis":"x","y":["Los Angeles"],"yaxis":"y","type":"histogram","opacity":0.7},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"city=%{y}<br>sum of questions=%{x}<extra></extra>","legendgroup":"Portland","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Portland","offsetgroup":"Portland","orientation":"h","showlegend":true,"x":[3939.0],"xaxis":"x","y":["Portland"],"yaxis":"y","type":"histogram","opacity":0.7},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"city=%{y}<br>sum of questions=%{x}<extra></extra>","legendgroup":"Boston","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Boston","offsetgroup":"Boston","orientation":"h","showlegend":true,"x":[3679.0],"xaxis":"x","y":["Boston"],"yaxis":"y","type":"histogram","opacity":0.7},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"city=%{y}<br>sum of questions=%{x}<extra></extr ...

# %%
def scatter_world_map(data, category, size):
    user_category = data.groupby(category, as_index=False).sum()
    user_category['Code'] = user_category[category].map(country_codes)
    
    # Plot
    map_fig = px.scatter_geo(user_category,
                     locations = 'Code',
                     projection = 'orthographic',
                     title=f'Total {size} by country',
                     color = category,
                     opacity=.7,
                     size=size,
                     hover_name=category,
                     hover_data=['views', 'questions', 'activitymonthlyduration', 'fame']
    )
    map_fig.layout.template = 'plotly_dark'
    return map_fig.show()

# %%
scatter_world_map(user_d, 'country', 'views')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="5907e20a-b1a9-468a-9335-6bbfbdc7a4f5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5907e20a-b1a9-468a-9335-6bbfbdc7a4f5")) {                    Plotly.newPlot(                        "5907e20a-b1a9-468a-9335-6bbfbdc7a4f5",                        [{"customdata":[[61.0,9.0,0.02,58.0]],"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>country=Albania<br>views=%{customdata[0]}<br>Code=%{location}<br>questions=%{customdata[1]}<br>activitymonthlyduration=%{customdata[2]}<br>fame=%{customdata[3]}<extra></extra>","hovertext":["Albania"],"legendgroup":"Albania","locations":["ALB"],"marker":{"color":"#636efa","opacity":0.7,"size":[61.0],"sizemode":"area","sizeref":13604.205,"symbol":"circle"},"mode":"markers","name":"Albania","showlegend":true,"type":"scattergeo"},{"customdata":[[491.0,20.0,12.809999999999999,5935.0]],"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>country=Algeria<br>views=%{customdata[0]}<br>Code=%{location}<br>questions=%{customdata[1]}<br>activitymonthlyduration=%{customdata[2]}<br>fame=%{customdata[3]}<extra></extra>","hovertext":["Algeria"],"legendgroup":"Algeria","locations":["DZA"],"marker":{"color":"#EF553B","opacity":0.7,"size":[491.0],"sizemode":"area","sizeref":13604.205,"symbol":"circle"},"mode":"markers","name":"Algeria","showlegend":true,"type":"scattergeo"},{"customdata":[[30223.0,1452.0,836.46,422287.0]],"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>country=Argentina<br>views=%{customdata[0]}<br>Code=%{location}<br>questions=%{customdata[1]}<br>activitymonthlyduration=%{customdata[2]}<br>fame=%{customdata[3]}<extra></extra>","hovertext":["Argentina"],"legendgroup":"Argentina","locations":["ARG"],"marker":{"color":"#00cc96","opacity":0.7,"size":[30223.0],"sizemode":"area","sizeref":13604.205,"symbol":"circle"},"mode":"markers","name":"Argentina","showlegend":true,"type":"scattergeo"},{"customdata":[[3082.0,267.0,57.730000000000004,33747.0]],"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>country=Armenia<br>views=%{customdata[0]}<br>Code=%{location}<br>questions=%{customdata[1]}<br>activitymonthlyduration=%{customdata[2]}<br>fame=%{customdata[3]}<extra></extra>","hovertext":["Armenia"],"legendgroup":"Armenia","locations":["ARM"],"marker":{"color":"#ab63fa","opacity":0.7,"size":[3082.0],"sizemode":"area","sizeref":13604.205,"symbol":"circle"},"mode":"markers","name":"Armenia","showlegend":true,"type":"scattergeo"},{"customdata":[[386562.0,14448.0,7186.94,4122281.0]],"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>country=Australia<br>views=%{customdata[0]}<br>Code=%{location}<br>questions=%{customdata[1]}<br>activitymonthlyduration=%{customdata[2]}<br>fame=%{customdata[3]}<extra></extra>","hovertext":["Australia"],"legendgroup":"Australia","locations":["AUS"],"marker":{"color":"#FFA15A","opacity":0.7,"size":[386562.0],"sizemode":"area","sizeref":13604.205,"symbol":"circle"},"mode":"markers","name":"Australia","showlegend":true,"type":"scattergeo"},{"customdata":[[75351.0,2076.0,1193.72,757894.0]],"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>country=Austria<br>views=%{customdata[0]}<br>Code=%{location}<br>questions=%{customdata[1]}<br>activitymonthlyduration=%{customdata[2]}<br>fame=%{customdata[3]}<extra></extra>","hovertext":["Austria"],"legendgroup":"Austria","locations":["AUT"],"marker":{"color":"#19d3f3","opacity":0.7,"size":[75351.0],"sizemode":"area","sizeref":13604.205,"symbol":"circle"},"mode":"markers","name":"Austria","showlegend":true,"type":"scattergeo"},{"customdata":[[285.0,23.0,23.369999999999997,1301.0]],"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>country=Azerbaijan<br>views=%{customdata[0]}<br>Code=%{location}<br>questions=%{customdat ...

# %%
scatter_world_map(user_d, 'country', 'questions')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="44bd56ec-0a4d-440a-afa4-f7c8f302c02a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("44bd56ec-0a4d-440a-afa4-f7c8f302c02a")) {                    Plotly.newPlot(                        "44bd56ec-0a4d-440a-afa4-f7c8f302c02a",                        [{"customdata":[[61.0,9.0,0.02,58.0]],"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>country=Albania<br>questions=%{customdata[1]}<br>Code=%{location}<br>views=%{customdata[0]}<br>activitymonthlyduration=%{customdata[2]}<br>fame=%{customdata[3]}<extra></extra>","hovertext":["Albania"],"legendgroup":"Albania","locations":["ALB"],"marker":{"color":"#636efa","opacity":0.7,"size":[9.0],"sizemode":"area","sizeref":367.99,"symbol":"circle"},"mode":"markers","name":"Albania","showlegend":true,"type":"scattergeo"},{"customdata":[[491.0,20.0,12.809999999999999,5935.0]],"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>country=Algeria<br>questions=%{customdata[1]}<br>Code=%{location}<br>views=%{customdata[0]}<br>activitymonthlyduration=%{customdata[2]}<br>fame=%{customdata[3]}<extra></extra>","hovertext":["Algeria"],"legendgroup":"Algeria","locations":["DZA"],"marker":{"color":"#EF553B","opacity":0.7,"size":[20.0],"sizemode":"area","sizeref":367.99,"symbol":"circle"},"mode":"markers","name":"Algeria","showlegend":true,"type":"scattergeo"},{"customdata":[[30223.0,1452.0,836.46,422287.0]],"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>country=Argentina<br>questions=%{customdata[1]}<br>Code=%{location}<br>views=%{customdata[0]}<br>activitymonthlyduration=%{customdata[2]}<br>fame=%{customdata[3]}<extra></extra>","hovertext":["Argentina"],"legendgroup":"Argentina","locations":["ARG"],"marker":{"color":"#00cc96","opacity":0.7,"size":[1452.0],"sizemode":"area","sizeref":367.99,"symbol":"circle"},"mode":"markers","name":"Argentina","showlegend":true,"type":"scattergeo"},{"customdata":[[3082.0,267.0,57.730000000000004,33747.0]],"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>country=Armenia<br>questions=%{customdata[1]}<br>Code=%{location}<br>views=%{customdata[0]}<br>activitymonthlyduration=%{customdata[2]}<br>fame=%{customdata[3]}<extra></extra>","hovertext":["Armenia"],"legendgroup":"Armenia","locations":["ARM"],"marker":{"color":"#ab63fa","opacity":0.7,"size":[267.0],"sizemode":"area","sizeref":367.99,"symbol":"circle"},"mode":"markers","name":"Armenia","showlegend":true,"type":"scattergeo"},{"customdata":[[386562.0,14448.0,7186.94,4122281.0]],"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>country=Australia<br>questions=%{customdata[1]}<br>Code=%{location}<br>views=%{customdata[0]}<br>activitymonthlyduration=%{customdata[2]}<br>fame=%{customdata[3]}<extra></extra>","hovertext":["Australia"],"legendgroup":"Australia","locations":["AUS"],"marker":{"color":"#FFA15A","opacity":0.7,"size":[14448.0],"sizemode":"area","sizeref":367.99,"symbol":"circle"},"mode":"markers","name":"Australia","showlegend":true,"type":"scattergeo"},{"customdata":[[75351.0,2076.0,1193.72,757894.0]],"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>country=Austria<br>questions=%{customdata[1]}<br>Code=%{location}<br>views=%{customdata[0]}<br>activitymonthlyduration=%{customdata[2]}<br>fame=%{customdata[3]}<extra></extra>","hovertext":["Austria"],"legendgroup":"Austria","locations":["AUT"],"marker":{"color":"#19d3f3","opacity":0.7,"size":[2076.0],"sizemode":"area","sizeref":367.99,"symbol":"circle"},"mode":"markers","name":"Austria","showlegend":true,"type":"scattergeo"},{"customdata":[[285.0,23.0,23.369999999999997,1301.0]],"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>country=Azerbaijan<br>questions=%{customdata[1]}<br>Code=%{location}<br>views=%{customdata[0]}<br>activitymonthly ...

# %%
scatter_world_map(user_d, 'country', 'fame')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="4a997f41-5877-4288-aa42-1d44fb623852" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4a997f41-5877-4288-aa42-1d44fb623852")) {                    Plotly.newPlot(                        "4a997f41-5877-4288-aa42-1d44fb623852",                        [{"customdata":[[61.0,9.0,0.02,58.0]],"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>country=Albania<br>fame=%{customdata[3]}<br>Code=%{location}<br>views=%{customdata[0]}<br>questions=%{customdata[1]}<br>activitymonthlyduration=%{customdata[2]}<extra></extra>","hovertext":["Albania"],"legendgroup":"Albania","locations":["ALB"],"marker":{"color":"#636efa","opacity":0.7,"size":[58.0],"sizemode":"area","sizeref":121006.98,"symbol":"circle"},"mode":"markers","name":"Albania","showlegend":true,"type":"scattergeo"},{"customdata":[[491.0,20.0,12.809999999999999,5935.0]],"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>country=Algeria<br>fame=%{customdata[3]}<br>Code=%{location}<br>views=%{customdata[0]}<br>questions=%{customdata[1]}<br>activitymonthlyduration=%{customdata[2]}<extra></extra>","hovertext":["Algeria"],"legendgroup":"Algeria","locations":["DZA"],"marker":{"color":"#EF553B","opacity":0.7,"size":[5935.0],"sizemode":"area","sizeref":121006.98,"symbol":"circle"},"mode":"markers","name":"Algeria","showlegend":true,"type":"scattergeo"},{"customdata":[[30223.0,1452.0,836.46,422287.0]],"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>country=Argentina<br>fame=%{customdata[3]}<br>Code=%{location}<br>views=%{customdata[0]}<br>questions=%{customdata[1]}<br>activitymonthlyduration=%{customdata[2]}<extra></extra>","hovertext":["Argentina"],"legendgroup":"Argentina","locations":["ARG"],"marker":{"color":"#00cc96","opacity":0.7,"size":[422287.0],"sizemode":"area","sizeref":121006.98,"symbol":"circle"},"mode":"markers","name":"Argentina","showlegend":true,"type":"scattergeo"},{"customdata":[[3082.0,267.0,57.730000000000004,33747.0]],"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>country=Armenia<br>fame=%{customdata[3]}<br>Code=%{location}<br>views=%{customdata[0]}<br>questions=%{customdata[1]}<br>activitymonthlyduration=%{customdata[2]}<extra></extra>","hovertext":["Armenia"],"legendgroup":"Armenia","locations":["ARM"],"marker":{"color":"#ab63fa","opacity":0.7,"size":[33747.0],"sizemode":"area","sizeref":121006.98,"symbol":"circle"},"mode":"markers","name":"Armenia","showlegend":true,"type":"scattergeo"},{"customdata":[[386562.0,14448.0,7186.94,4122281.0]],"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>country=Australia<br>fame=%{customdata[3]}<br>Code=%{location}<br>views=%{customdata[0]}<br>questions=%{customdata[1]}<br>activitymonthlyduration=%{customdata[2]}<extra></extra>","hovertext":["Australia"],"legendgroup":"Australia","locations":["AUS"],"marker":{"color":"#FFA15A","opacity":0.7,"size":[4122281.0],"sizemode":"area","sizeref":121006.98,"symbol":"circle"},"mode":"markers","name":"Australia","showlegend":true,"type":"scattergeo"},{"customdata":[[75351.0,2076.0,1193.72,757894.0]],"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>country=Austria<br>fame=%{customdata[3]}<br>Code=%{location}<br>views=%{customdata[0]}<br>questions=%{customdata[1]}<br>activitymonthlyduration=%{customdata[2]}<extra></extra>","hovertext":["Austria"],"legendgroup":"Austria","locations":["AUT"],"marker":{"color":"#19d3f3","opacity":0.7,"size":[757894.0],"sizemode":"area","sizeref":121006.98,"symbol":"circle"},"mode":"markers","name":"Austria","showlegend":true,"type":"scattergeo"},{"customdata":[[285.0,23.0,23.369999999999997,1301.0]],"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>country=Azerbaijan<br>fame=%{customdata[3]}<br>Code=%{location}<br>views=%{customdat ...

# %% [markdown]
# ### Numerical
# **QUESTIONS**
# - Which city and gender have the highest views?
# - Which country has the lowest fame?

# %%
def correlation(data):
    corrmat = data.corr()
    fig = px.imshow(corrmat, color_continuous_scale=["#caf0f8","#03071e", "#370617", "#70e000"],
                    title='Heatmap User Description')
    fig.layout.template = 'plotly_dark'
    return fig.show()

correlation(user_d)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="3ceb4968-bf3a-45b8-a665-76b0ae86e636" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3ceb4968-bf3a-45b8-a665-76b0ae86e636")) {                    Plotly.newPlot(                        "3ceb4968-bf3a-45b8-a665-76b0ae86e636",                        [{"coloraxis":"coloraxis","name":"0","x":["id","profile_length","activitymonthlyduration","highagreement","lowagreement","views","fame","questions","answers","comments","edits","tokens"],"y":["id","profile_length","activitymonthlyduration","highagreement","lowagreement","views","fame","questions","answers","comments","edits","tokens"],"z":[[1.0,-0.062956404743602,-0.24384388071972082,-0.10834175214440493,-0.017769080759556743,-0.06379564382760798,-0.13646604548921143,-0.043093407982798614,-0.07006717782857906,-0.034943848457351316,-0.04423697916794434,-0.16197456863187182],[-0.062956404743602,1.0,0.11970463076198283,0.1612920040261217,0.11857429097282142,0.11541686433470984,0.1505582510290274,0.06640078476221568,0.14417956479435104,0.13978591888653072,0.16071960707037047,0.1739486759897414],[-0.24384388071972082,0.11970463076198283,1.0,0.19670050579627107,0.03000527033334912,0.06608910955567916,0.1516301146180817,0.15270478749404154,0.12262936645824603,0.09141270684735932,0.08841056311290249,0.2389971287546914],[-0.10834175214440493,0.1612920040261217,0.19670050579627107,1.0,0.23693716276337862,0.29936622500519033,0.5402328885427552,0.26309252568641717,0.526974216013498,0.5457540382990825,0.4701114273259241,0.6061494937395356],[-0.017769080759556743,0.11857429097282142,0.03000527033334912,0.23693716276337862,1.0,0.34119845924042763,0.21392593047350342,0.025155531087376552,0.2212463771049442,0.3142886935419918,0.7542338125601387,0.18697692603883748],[-0.06379564382760798,0.11541686433470984,0.06608910955567916,0.29936622500519033,0.34119845924042763,1.0,0.4470432623129995,0.09815272755648988,0.37740529486862007,0.3677512286557977,0.4833319925420896,0.40306355525210347],[-0.13646604548921143,0.1505582510290274,0.1516301146180817,0.5402328885427552,0.21392593047350342,0.4470432623129995,1.0,0.2660293373530103,0.8120749414380435,0.6860542226809445,0.5019356654239853,0.8679592534395484],[-0.043093407982798614,0.06640078476221568,0.15270478749404154,0.26309252568641717,0.025155531087376552,0.09815272755648988,0.2660293373530103,1.0,0.12731865812255422,0.17049587595668453,0.20573066509399685,0.6172112133099432],[-0.07006717782857906,0.14417956479435104,0.12262936645824603,0.526974216013498,0.2212463771049442,0.37740529486862007,0.8120749414380435,0.12731865812255422,1.0,0.8264107212164747,0.5440823507302476,0.6828923192618244],[-0.034943848457351316,0.13978591888653072,0.09141270684735932,0.5457540382990825,0.3142886935419918,0.3677512286557977,0.6860542226809445,0.17049587595668453,0.8264107212164747,1.0,0.603019324020564,0.6094569749477937],[-0.04423697916794434,0.16071960707037047,0.08841056311290249,0.4701114273259241,0.7542338125601387,0.4833319925420896,0.5019356654239853,0.20573066509399685,0.5440823507302476,0.603019324020564,1.0,0.49812653306258237],[-0.16197456863187182,0.1739486759897414,0.2389971287546914,0.6061494937395356,0.18697692603883748,0.40306355525210347,0.8679592534395484,0.6172112133099432,0.6828923192618244,0.6094569749477937,0.49812653306258237,1.0]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}<br>y: %{y}<br>color: %{z}<extra></extra>"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"patte ...

# %% [markdown]
# #### Views

# %%
def numerical_histogram(data, x, color):
    fig = px.histogram(data, x=x,
                      title=f'Histogram of {x}',
                      color_discrete_sequence=[color])
    fig.layout.template = 'plotly_dark'
    return fig.show()

# %%
view_zero = user_d[user_d['views']<150]
numerical_histogram(view_zero, 'views', 'rosybrown')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="697ee5ee-d0c8-4930-ab9c-e77feeffbacb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("697ee5ee-d0c8-4930-ab9c-e77feeffbacb")) {                    Plotly.newPlot(                        "697ee5ee-d0c8-4930-ab9c-e77feeffbacb",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"views=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"rosybrown","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[52.0,19.0,35.0,98.0,9.0,37.0,7.0,5.0,107.0,111.0,118.0,56.0,17.0,9.0,93.0,45.0,122.0,35.0,112.0,19.0,26.0,148.0,57.0,22.0,8.0,2.0,46.0,107.0,2.0,27.0,39.0,114.0,48.0,7.0,148.0,9.0,144.0,36.0,12.0,7.0,69.0,105.0,80.0,71.0,48.0,23.0,30.0,0.0,44.0,129.0,16.0,11.0,103.0,55.0,29.0,80.0,14.0,85.0,33.0,41.0,7.0,33.0,64.0,7.0,62.0,15.0,18.0,45.0,17.0,0.0,24.0,75.0,104.0,9.0,90.0,30.0,5.0,13.0,29.0,4.0,33.0,25.0,22.0,49.0,116.0,14.0,55.0,148.0,49.0,69.0,29.0,32.0,4.0,101.0,16.0,76.0,78.0,10.0,9.0,7.0,56.0,3.0,54.0,67.0,74.0,101.0,8.0,141.0,92.0,109.0,124.0,70.0,79.0,74.0,106.0,33.0,28.0,118.0,5.0,27.0,3.0,17.0,93.0,34.0,99.0,77.0,89.0,22.0,10.0,13.0,135.0,2.0,25.0,18.0,5.0,31.0,78.0,38.0,5.0,4.0,66.0,72.0,26.0,135.0,9.0,44.0,121.0,124.0,41.0,9.0,52.0,12.0,87.0,43.0,19.0,11.0,128.0,31.0,68.0,125.0,45.0,21.0,12.0,77.0,61.0,15.0,38.0,36.0,53.0,65.0,3.0,59.0,4.0,130.0,18.0,100.0,38.0,123.0,21.0,19.0,73.0,29.0,128.0,60.0,0.0,117.0,39.0,19.0,37.0,55.0,13.0,8.0,145.0,2.0,64.0,29.0,35.0,97.0,108.0,42.0,9.0,20.0,31.0,6.0,9.0,25.0,105.0,31.0,1.0,102.0,25.0,72.0,120.0,97.0,42.0,89.0,73.0,55.0,10.0,56.0,56.0,16.0,69.0,53.0,82.0,53.0,143.0,41.0,125.0,17.0,3.0,24.0,130.0,123.0,9.0,131.0,18.0,1.0,65.0,103.0,12.0,127.0,8.0,0.0,123.0,103.0,43.0,76.0,8.0,145.0,11.0,89.0,67.0,7.0,24.0,50.0,47.0,84.0,23.0,21.0,27.0,87.0,22.0,14.0,43.0,91.0,7.0,53.0,4.0,60.0,11.0,145.0,135.0,87.0,48.0,9.0,60.0,89.0,52.0,3.0,56.0,53.0,16.0,137.0,120.0,44.0,118.0,79.0,47.0,68.0,8.0,39.0,105.0,35.0,20.0,57.0,48.0,28.0,31.0,122.0,9.0,14.0,68.0,137.0,123.0,43.0,6.0,86.0,3.0,2.0,41.0,72.0,5.0,18.0,131.0,40.0,112.0,2.0,89.0,16.0,17.0,5.0,59.0,127.0,21.0,27.0,46.0,126.0,89.0,65.0,140.0,73.0,138.0,32.0,15.0,15.0,119.0,7.0,82.0,93.0,3.0,3.0,32.0,92.0,92.0,105.0,51.0,14.0,50.0,84.0,147.0,28.0,65.0,13.0,26.0,18.0,99.0,66.0,114.0,31.0,52.0,137.0,6.0,56.0,120.0,74.0,77.0,10.0,128.0,34.0,59.0,40.0,73.0,28.0,28.0,98.0,84.0,142.0,8.0,78.0,23.0,61.0,85.0,95.0,27.0,97.0,103.0,141.0,50.0,7.0,55.0,22.0,28.0,55.0,38.0,4.0,90.0,110.0,87.0,108.0,135.0,145.0,9.0,54.0,63.0,58.0,19.0,3.0,30.0,71.0,30.0,15.0,62.0,64.0,42.0,3.0,71.0,7.0,21.0,98.0,29.0,6.0,144.0,15.0,32.0,72.0,14.0,34.0,72.0,67.0,51.0,68.0,9.0,27.0,70.0,4.0,143.0,35.0,95.0,28.0,21.0,64.0,34.0,5.0,61.0,85.0,32.0,69.0,131.0,26.0,8.0,13.0,80.0,8.0,18.0,137.0,70.0,36.0,4.0,49.0,47.0,7.0,149.0,94.0,29.0,5.0,83.0,146.0,1.0,99.0,55.0,34.0,119.0,74.0,13.0,3.0,14.0,38.0,54.0,145.0,115.0,38.0,100.0,91.0,46.0,31.0,123.0,46.0,53.0,111.0,10.0,22.0,5.0,10.0,5.0,67.0,50.0,2.0,31.0,19.0,10.0,9.0,127.0,69.0,88.0,148.0,23.0,106.0,8.0,61.0,44.0,48.0,82.0,10.0,7.0,30.0,102.0,6.0,59.0,22.0,125.0,53.0,108.0,49.0,149.0,83.0,40.0,65.0,5.0,25.0,63.0,27.0,22.0,60.0,44.0,106.0,136.0,140.0,86.0,48.0,55.0,14.0,112.0,3.0,31.0,69.0,48.0,140.0,13.0,87.0,24.0,10.0,25.0,47.0,126.0,43.0,15.0,45.0,10.0,4.0,32.0,116.0,95.0,14.0,11.0,138.0,101.0,45.0,11.0,53.0,121.0,108.0,11.0,69.0,50.0,26.0,18.0,30.0,29.0,57.0,20.0,103.0,5.0,5.0,62.0,146.0,87.0,137.0,48.0,21.0,18.0,62.0,118.0,120.0,2.0,24.0,72.0,136.0,15.0,2.0,135.0,50.0,5.0,3.0,3.0,8.0,37.0,3.0,100.0,149.0,148.0,2.0,9.0,106.0,74.0,82.0,8.0,59.0,53.0,115.0,18.0,13.0,122.0,12.0,44.0,3.0,59.0,58.0,16.0,70.0,106.0,143.0,23.0,11.0,69.0,8.0,74.0,64.0,87.0,1 ...

# %% [markdown]
# **Conclusion**
# - Views is right skewed
# - There is a lot of data and `outliers in views`, which makes our data `skew`. So we will lower the amount of views in our data because it is clear that less people have more views.

# %%
one_million = user_d[user_d['views']>100000]
(one_million['state']
 .value_counts()
 .reset_index()[:10]
 .rename(columns={'index':'state', 'state':'count'})
)
# Out:
#                 state  count
# 0      North Carolina      1
# 1          California      1
# 2       South Denmark      1
# 3            New York      1
# 4          Canterbury      1
# 5               SG.01      1
# 6  Primorsko-Goranska      0
# 7       Plzeňský kraj      0
# 8           Pomerania      0
# 9               Ponce      0

# %%
user_d[user_d['views']>500000]
# Out:
#      id        city       state country gender  profile_length  \
# 489   1  El Cerrito  California      US   male            64.0
#
#      activitymonthlyduration  highagreement  lowagreement     views     fame  \
# 489                    12.81         3390.0        1311.0  585755.0  60897.0
#
#      questions  answers  comments   edits  tokens
# 489       16.0    127.0     382.0  5066.0   343.0

# %%
user_d[user_d['views']<5][:10]
# Out:
#          id       city                state    country  gender  \
# 81   351694    Chennai           Tamil Nadu      India    male
# 88   227707  Hong Kong  Central and Western  Hong Kong    male
# 140  287518      Paris        Île-de-France     France    male
# 204  412145   Montreal               Quebec     Canada    male
# 241  352549     Dalian             Liaoning      China    male
# 274  228509    Atlanta              Georgia         US    male
# 293  170049     Berlin               Berlin    Germany    male
# 345  170466  Darmstadt                Hesse    Germany    male
# 375  229026   Montreal               Quebec     Canada    male
# 400  170764   Leesburg             Virginia         US  female
#
#      profile_length  activitymonthlyduration  highagreement  lowagreement  \
# 81              1.0                     0.00            0.0           0.0
# 88              1.0                     2.24            0.0           0.0
# 140             1.0                     8.65            1.0           0.0
# 204             1.0                     1.97            0.0           0.0
# 241             3.0                     0.06            0.0           0.0
# 274             4.0                     1.63            0.0           0.0
# 293             1.0                     0.37            4.0           0.0
# 345             1.0                     0.29            1.0           0.0
# 375             1.0                     0.00            0.0           0.0
# 400             4.0                     9.08            0.0           0.0
#
#      views  fame  questions  answers  comments  edits  tokens
# 81     2.0   3.0        2.0     14.0       1.0    6.0     2.0
# 88     2.0   1.0        7.0     14.0      24.0   43.0     1.0
# 140    0.0  26.0        7.0      1.0      24.0    1.0     2.0
# 204    0.0   1.0        7.0     14.0      24.0   43.0    27.0
# 241    4.0  11.0        1.0     14.0       1.0    6.0     3.0
# 274    4.0  23.0        1.0     14.0       2.0    3.0     6.0
# 293    3.0  36.0        7.0      2.0      24.0    3.0     3.0
# 345    3.0  21.0        7.0      1.0      24.0    2.0     3.0
# 375    2.0   1.0        1.0     14.0      24.0    3.0    27.0
# 400    4.0   5.0        2.0     14.0       3.0    6.0     3.0

# %%
def categorical_feature(x):
    if x < 35:
        return 'Low Views'
    elif x < 70:
        return 'Some Views'
    elif x < 105:
        return 'Medium Views'
    elif pd.isnull(x):
        return np.nan
    else:
        return 'High Views'

# %%
view_zero['view_feature'] = view_zero['views'].map(categorical_feature)
view_zero[['country','city','gender','views', 'view_feature']]
# Out:
#            country           city  gender  views  view_feature
# 2           France       Chaville    male   52.0    Some Views
# 4               US         Denver    male   19.0     Low Views
# 13              US     Pittsfield    male   35.0    Some Views
# 14     New Zealand       Auckland    male   98.0  Medium Views
# 22              US        Chicago    male    9.0     Low Views
# ...            ...            ...     ...    ...           ...
# 27012       France         Nantes    male    7.0     Low Views
# 27017           US        Chicago    male    1.0     Low Views
# 27020           US    Minneapolis  female   35.0    Some Views
# 27023      Ireland         Dublin    male  136.0    High Views
# 27027           US  San Francisco    male   48.0    Some Views
#
# [10379 rows x 5 columns]

# %%
hist_categorical_views = (view_zero['view_feature']
 .value_counts()
 .reset_index()
 .rename(columns=({'index': 'views', 'view_feature': 'count'}))
)
fig = px.histogram(hist_categorical_views, x='count', y='views',
                      title='Histogram of View Feature',
                      color='views',
                      color_discrete_sequence=['#005f73', '#ee9b00', '#ae2012', '#9b2226'])
fig.layout.template = 'plotly_dark'
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="bac03c3a-552b-4d30-b3cb-f959812c75f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bac03c3a-552b-4d30-b3cb-f959812c75f3")) {                    Plotly.newPlot(                        "bac03c3a-552b-4d30-b3cb-f959812c75f3",                        [{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"views=%{y}<br>sum of count=%{x}<extra></extra>","legendgroup":"Low Views","marker":{"color":"#005f73","pattern":{"shape":""}},"name":"Low Views","offsetgroup":"Low Views","orientation":"h","showlegend":true,"x":[4587],"xaxis":"x","y":["Low Views"],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"views=%{y}<br>sum of count=%{x}<extra></extra>","legendgroup":"Some Views","marker":{"color":"#ee9b00","pattern":{"shape":""}},"name":"Some Views","offsetgroup":"Some Views","orientation":"h","showlegend":true,"x":[2564],"xaxis":"x","y":["Some Views"],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"views=%{y}<br>sum of count=%{x}<extra></extra>","legendgroup":"Medium Views","marker":{"color":"#ae2012","pattern":{"shape":""}},"name":"Medium Views","offsetgroup":"Medium Views","orientation":"h","showlegend":true,"x":[1729],"xaxis":"x","y":["Medium Views"],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"views=%{y}<br>sum of count=%{x}<extra></extra>","legendgroup":"High Views","marker":{"color":"#9b2226","pattern":{"shape":""}},"name":"High Views","offsetgroup":"High Views","orientation":"h","showlegend":true,"x":[1499],"xaxis":"x","y":["High Views"],"yaxis":"y","type":"histogram"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""}," ...

# %%
view_zero[view_zero['view_feature']=='High Views'].sort_values(by='views', ascending=False)[:10]
# Out:
#            id       city           state    country  gender  profile_length  \
# 4096   351975  Barcelona       Catalonia      Spain    male            45.0
# 6933    44605     Austin           Texas         US    male             4.0
# 14476   51059  Reykjavík  Capital Region    Iceland    male             5.0
# 21683  296696   New York        New York         US    male             1.0
# 4321   105667     Austin           Texas         US    male            90.0
# 4267    40498      Delhi           Delhi      India    male             1.0
# 22155   53155   New York        New York         US    male            26.0
# 21395    4341  Melbourne        Victoria  Australia  female            22.0
# 11023  290844  Nashville       Tennessee         US    male             1.0
# 14787  177040  Bengaluru       Karnataka      India    male            64.0
#
#        activitymonthlyduration  highagreement  lowagreement  views    fame  \
# 4096                     11.01           92.0           1.0  149.0  2113.0
# 6933                     12.47           85.0          18.0  149.0  1275.0
# 14476                    12.25           10.0           0.0  149.0   725.0
# 21683                     9.21           28.0           1.0  149.0  1466.0
# 4321                     11.95           72.0           0.0  149.0   821.0
# 4267                     10.57           13.0           0.0  149.0   593.0
# 22155                    10.18           39.0           0.0  149.0   812.0
# 21395                    12.74          174.0           1.0  149.0  1434.0
# 11023                    10.52          331.0           0.0  149.0  1532.0
# 14787                    11.69           19.0           0.0  149.0   626.0
#
#        questions  answers  comments  edits  tokens view_feature
# 4096        31.0     34.0      80.0  161.0    62.0   High Views
# 6933         6.0     49.0     151.0   81.0    35.0   High Views
# 14476        4.0      2.0      15.0   23.0    22.0   High Views
# 21683        1.0     24.0      21.0   56.0    21.0   High Views
# 4321         4.0     14.0      17.0   43.0    23.0   High Views
# 4267        12.0      2.0      13.0   39.0    25.0   High Views
# 22155        7.0     38.0      15.0   52.0    18.0   High Views
# 21395        6.0     12.0       9.0   35.0    37.0   High Views
# 11023       44.0     12.0      87.0  161.0    55.0   High Views
# 14787       43.0      5.0      73.0  143.0    34.0   High Views

# %%
view_zero['country'].value_counts().reset_index()[:10]
# Out:
#                 index  country
# 0                  US     4634
# 1                  UK      881
# 2              Canada      615
# 3               India      583
# 4           Australia      403
# 5             Germany      354
# 6              France      185
# 7              Sweden      175
# 8  Russian Federation      173
# 9         Netherlands      140

# %% [markdown]
# #### monthly duration

# %%
user_d['activitymonthlyduration'].value_counts()
# Out:
# 11.45    183
# 11.44    173
# 10.99    168
# 10.78    168
# 10.79    157
#         ...
# 3.75       1
# 3.68       1
# 4.64       1
# 4.67       1
# 3.65       1
# Name: activitymonthlyduration, Length: 1271, dtype: int64

# %%
amd = user_d[(user_d['activitymonthlyduration']>0.05) & (user_d['activitymonthlyduration']<12.00)]

# %% [markdown]
# **Conclusion**
# - There is a lot of people with less than a month so we can remove some just to see our data better

# %%
(amd['activitymonthlyduration']
 .value_counts()
 .reset_index()[:10]
 .rename(columns={'index':'monthly_duration', 'activitymonthlyduration':'count'})
)
# Out:
#    monthly_duration  count
# 0             11.45    183
# 1             11.44    173
# 2             10.78    168
# 3             10.99    168
# 4             10.79    157
# 5             11.21    153
# 6             11.68    152
# 7             10.98    150
# 8             10.80    148
# 9             10.81    147

# %%
numerical_histogram(amd, 'activitymonthlyduration', 'saddlebrown')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="4ea4566f-b1d0-47c3-bf80-9721210c0648" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4ea4566f-b1d0-47c3-bf80-9721210c0648")) {                    Plotly.newPlot(                        "4ea4566f-b1d0-47c3-bf80-9721210c0648",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"activitymonthlyduration=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"saddlebrown","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[9.8,10.53,1.72,11.74,10.95,10.82,10.82,10.28,10.82,4.55,8.84,7.58,9.76,10.68,0.33,10.08,11.74,11.01,11.68,11.32,4.8,0.28,9.07,10.14,11.24,7.7,11.23,10.87,11.74,11.47,6.63,11.47,2.15,9.14,10.85,1.01,10.35,2.57,11.73,10.5,10.54,11.05,2.24,10.82,11.44,11.1,11.58,10.99,11.74,10.08,11.01,8.15,1.55,0.09,5.79,0.42,10.72,10.31,4.44,11.4,9.51,9.55,10.94,6.78,11.56,3.3,10.03,6.57,5.24,8.65,4.35,5.36,9.42,10.95,11.74,9.44,8.2,11.24,0.79,11.73,11.96,6.22,11.47,10.83,9.81,4.33,6.4,10.07,10.8,11.47,10.63,10.14,2.49,11.01,8.1,8.71,11.7,8.85,1.97,10.08,10.78,11.51,11.71,10.69,8.37,5.43,11.73,2.96,11.01,0.31,8.65,10.7,6.89,10.79,0.06,5.43,0.52,1.93,0.26,11.01,10.81,11.73,11.7,8.59,3.91,11.34,0.49,10.59,11.9,7.29,10.68,6.21,1.63,11.73,1.36,11.22,11.24,10.79,2.05,11.8,0.37,11.22,11.17,10.82,9.68,10.82,11.7,11.47,11.72,1.58,7.93,11.39,11.73,9.79,11.42,11.71,11.67,10.95,11.05,9.3,11.72,11.57,11.73,10.35,11.67,0.29,6.11,8.58,6.3,7.1,11.46,11.47,9.04,11.89,1.57,11.24,11.24,9.75,9.3,11.46,10.91,4.68,0.96,9.76,11.72,11.72,6.23,11.41,11.47,10.09,9.08,11.73,11.23,5.94,11.47,10.82,10.72,11.23,11.73,10.39,11.72,3.02,11.6,11.72,11.47,6.85,9.0,10.82,9.72,2.66,9.35,9.41,9.79,8.69,8.35,8.38,10.06,11.5,11.7,7.42,10.69,11.67,3.03,10.82,5.25,9.72,11.4,11.47,0.09,2.67,10.83,4.98,9.95,6.98,10.81,1.47,9.92,5.91,9.73,9.09,10.98,11.71,6.54,10.78,11.0,10.98,11.74,3.69,11.24,2.93,11.7,1.81,11.01,10.99,11.67,2.63,11.33,11.6,10.81,8.59,11.48,11.74,11.18,2.78,4.99,11.95,10.11,2.39,3.01,10.81,1.68,4.23,11.48,4.39,10.79,10.33,10.84,10.28,11.16,10.49,0.27,2.81,11.73,0.45,3.34,11.01,11.09,11.47,7.34,9.75,10.84,11.71,11.72,11.25,9.61,10.81,0.86,10.39,10.47,10.24,11.24,11.67,11.44,11.98,1.22,10.8,10.54,4.94,10.54,0.75,9.14,11.73,10.9,11.73,9.85,11.24,11.01,11.76,11.71,11.01,10.22,11.73,0.07,11.43,1.53,9.98,10.82,11.21,11.05,0.92,11.32,8.05,2.69,7.53,10.85,2.34,10.19,10.16,10.82,11.34,11.72,11.47,9.16,2.1,10.81,10.75,11.26,9.62,3.64,11.47,9.67,11.47,2.15,10.82,11.47,10.81,8.78,11.47,11.98,11.73,10.69,1.83,9.72,0.11,7.42,0.75,11.47,10.8,11.7,11.69,11.47,11.96,11.28,11.73,9.99,11.73,11.23,10.82,11.24,11.43,5.04,9.97,11.73,11.95,9.93,10.14,7.55,11.64,11.47,3.58,9.18,11.49,1.51,11.23,11.47,2.41,11.4,11.04,9.13,11.01,10.03,11.08,10.25,6.01,7.81,11.23,11.69,7.97,11.24,11.47,11.29,11.47,10.82,11.72,11.71,2.85,10.24,6.85,11.7,10.62,11.72,10.81,9.89,6.48,2.2,3.79,10.16,11.72,0.09,8.11,9.17,10.66,10.85,9.68,10.7,0.84,11.72,10.82,10.24,0.56,11.31,9.95,11.75,0.19,11.61,11.98,11.38,11.01,9.95,11.37,7.95,11.1,11.01,8.23,2.73,2.01,1.69,6.93,0.73,0.35,11.47,11.72,11.0,6.88,11.23,10.88,6.65,9.53,9.88,10.82,9.01,11.19,11.56,10.09,11.46,11.6,0.28,8.86,11.47,11.47,9.47,10.81,11.4,11.46,11.01,11.09,11.72,11.45,0.41,11.13,11.46,11.45,1.8,5.86,11.6,9.7,10.81,11.72,11.95,10.6,11.69,10.77,5.47,8.81,11.44,7.6,11.35,0.42,2.6,9.34,8.02,10.7,10.81,9.5,11.33,11.72,9.12,0.84,11.46,10.81,10.74,11.46,11.61,10.54,10.99,10.54,11.44,8.73,11.11,4.42,10.81,8.24,8.51,10.99,11.0,4.74,3.89,11.24,11.23,10.81,10.44,0.19,11.95,11.23,6.03,11.76,2.08,10.81,3.52,11.72,11.0,11.65,11.71,5.27,10.73,10.72,11.67,9.98,9.7,8.46,2.6,11.0,7.12,11.72,11.7,9.54,0.08,10.17,10.81,11.87,5.3,11.46,11.45,5.82,10.81,11.44,8.73,10.76,11.46,3.38,5.83,11. ...

# %%
def categorical_feature(x):
    if x < 1:
        return 0
    elif x < 2:
        return 1
    elif x < 3:
        return 2
    elif x < 4:
        return 3
    elif x < 5:
        return 4
    elif x < 6:
        return 5
    elif x < 7:
        return 6
    elif x < 8:
        return 7
    elif x < 9:
        return 8
    elif x < 10:
        return 9
    elif x < 11:
        return 10
    elif x < 12:
        return 11
    else:
        return 12
    
amd['monthly_feature'] = amd['activitymonthlyduration'].map(categorical_feature)

# %%
amd[['country','city','gender','activitymonthlyduration', 'monthly_feature']]
# Out:
#          country            city  gender  activitymonthlyduration  \
# 1             US      Marysville    male                     9.80
# 2         France        Chaville    male                    10.53
# 4             US          Denver    male                     1.72
# 5             US        New York    male                    11.74
# 11     Australia        Brisbane    male                    10.95
# ...          ...             ...     ...                      ...
# 27020         US     Minneapolis  female                     0.10
# 27021         US   San Francisco    male                    10.45
# 27022     France  Saint-Affrique    male                    11.93
# 27024      India       Ahmedabad    male                    11.93
# 27027         US   San Francisco    male                     8.85
#
#        monthly_feature
# 1                    9
# 2                   10
# 4                    1
# 5                   11
# 11                  10
# ...                ...
# 27020                0
# 27021               10
# 27022               11
# 27024               11
# 27027                8
#
# [14134 rows x 5 columns]

# %%
hist_categorical_monthly = (amd['monthly_feature']
 .value_counts()
 .reset_index()
 .rename(columns=({'index': 'monthly', 'monthly_feature': 'count'}))
)
fig = px.histogram(hist_categorical_monthly, x='monthly', y='count',
                   title='Histogram of View Feature',
                   color_discrete_sequence=['saddlebrown'],
                   nbins=35
                  )
fig.layout.template = 'plotly_dark'
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ac8d5d26-5177-4d22-b83a-b706a9d82b51" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ac8d5d26-5177-4d22-b83a-b706a9d82b51")) {                    Plotly.newPlot(                        "ac8d5d26-5177-4d22-b83a-b706a9d82b51",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"monthly=%{x}<br>sum of count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"saddlebrown","pattern":{"shape":""}},"name":"","nbinsx":35,"offsetgroup":"","orientation":"v","showlegend":false,"x":[11,10,9,0,8,7,6,5,1,2,4,3],"xaxis":"x","y":[5243,3344,1068,770,752,567,475,463,416,370,341,325],"yaxis":"y","type":"histogram"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar ...

# %% [markdown]
# #### fame

# %%
fame_data = user_d[user_d['fame']>1]

# %%
(user_d['fame']
 .value_counts()
 .reset_index()[:10]
 .rename(columns={'index':'fame', 'fame':'count'})
)
# Out:
#     fame  count
# 0    1.0    527
# 1   11.0    284
# 2   21.0    233
# 3   31.0    166
# 4   41.0    123
# 5  101.0    116
# 6   43.0     85
# 7   51.0     84
# 8   61.0     82
# 9   23.0     79

# %%
user_fame = user_d[(user_d['fame']>1)& (user_d['fame']<250)]

# %%
numerical_histogram(user_fame, 'fame', 'sienna')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="d54a6d8b-0c11-4ec1-9045-1f46555ce2b8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d54a6d8b-0c11-4ec1-9045-1f46555ce2b8")) {                    Plotly.newPlot(                        "d54a6d8b-0c11-4ec1-9045-1f46555ce2b8",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"fame=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"sienna","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[123.0,53.0,45.0,45.0,46.0,163.0,91.0,103.0,214.0,79.0,111.0,93.0,56.0,3.0,151.0,13.0,90.0,33.0,70.0,101.0,26.0,131.0,11.0,93.0,99.0,43.0,91.0,23.0,41.0,93.0,71.0,208.0,123.0,103.0,141.0,11.0,71.0,66.0,167.0,23.0,113.0,153.0,46.0,137.0,70.0,106.0,36.0,11.0,111.0,101.0,71.0,21.0,51.0,31.0,143.0,111.0,11.0,5.0,111.0,56.0,51.0,31.0,5.0,21.0,56.0,202.0,107.0,49.0,11.0,183.0,67.0,35.0,249.0,191.0,33.0,171.0,71.0,29.0,56.0,214.0,101.0,101.0,193.0,44.0,21.0,103.0,21.0,136.0,204.0,169.0,11.0,31.0,135.0,241.0,98.0,147.0,101.0,116.0,183.0,41.0,107.0,11.0,3.0,157.0,41.0,31.0,206.0,119.0,33.0,123.0,192.0,26.0,160.0,41.0,31.0,246.0,31.0,171.0,147.0,66.0,43.0,3.0,73.0,78.0,223.0,213.0,43.0,79.0,45.0,68.0,59.0,41.0,155.0,231.0,161.0,15.0,21.0,135.0,216.0,13.0,83.0,23.0,201.0,21.0,21.0,5.0,133.0,141.0,69.0,181.0,136.0,11.0,45.0,236.0,68.0,161.0,31.0,91.0,215.0,86.0,11.0,99.0,63.0,103.0,178.0,131.0,11.0,46.0,178.0,117.0,235.0,62.0,61.0,109.0,126.0,87.0,181.0,180.0,169.0,23.0,21.0,29.0,153.0,193.0,91.0,3.0,159.0,66.0,193.0,21.0,159.0,3.0,56.0,85.0,185.0,51.0,135.0,54.0,71.0,49.0,129.0,195.0,91.0,125.0,41.0,3.0,91.0,93.0,175.0,41.0,38.0,151.0,11.0,140.0,51.0,21.0,101.0,96.0,175.0,201.0,181.0,155.0,63.0,121.0,51.0,11.0,21.0,108.0,11.0,11.0,153.0,75.0,55.0,31.0,21.0,101.0,61.0,76.0,53.0,5.0,31.0,23.0,51.0,31.0,76.0,69.0,156.0,63.0,135.0,33.0,83.0,51.0,81.0,63.0,13.0,85.0,125.0,11.0,101.0,146.0,182.0,61.0,95.0,73.0,117.0,232.0,113.0,86.0,101.0,50.0,169.0,189.0,11.0,68.0,231.0,141.0,11.0,21.0,46.0,56.0,230.0,53.0,112.0,229.0,246.0,158.0,11.0,231.0,106.0,183.0,166.0,193.0,13.0,182.0,117.0,142.0,31.0,131.0,15.0,11.0,41.0,25.0,184.0,247.0,96.0,11.0,101.0,184.0,103.0,11.0,145.0,143.0,119.0,89.0,25.0,115.0,96.0,133.0,5.0,11.0,31.0,121.0,131.0,104.0,101.0,125.0,106.0,244.0,32.0,86.0,23.0,235.0,59.0,144.0,101.0,11.0,122.0,11.0,151.0,11.0,61.0,31.0,190.0,51.0,122.0,161.0,53.0,144.0,121.0,26.0,123.0,221.0,63.0,136.0,21.0,103.0,234.0,120.0,138.0,125.0,101.0,15.0,31.0,61.0,115.0,51.0,151.0,93.0,101.0,96.0,11.0,13.0,25.0,33.0,46.0,39.0,31.0,153.0,173.0,52.0,141.0,96.0,31.0,123.0,23.0,15.0,91.0,46.0,51.0,185.0,143.0,65.0,25.0,33.0,31.0,63.0,11.0,146.0,111.0,21.0,79.0,11.0,71.0,141.0,107.0,101.0,87.0,38.0,159.0,63.0,160.0,56.0,211.0,166.0,11.0,189.0,65.0,83.0,11.0,76.0,90.0,91.0,41.0,71.0,156.0,113.0,204.0,21.0,30.0,79.0,183.0,220.0,19.0,34.0,43.0,43.0,101.0,126.0,155.0,31.0,23.0,21.0,156.0,41.0,149.0,11.0,95.0,211.0,26.0,19.0,113.0,237.0,11.0,79.0,118.0,96.0,183.0,215.0,3.0,115.0,101.0,217.0,145.0,171.0,71.0,173.0,56.0,240.0,128.0,61.0,233.0,31.0,106.0,31.0,11.0,25.0,54.0,45.0,11.0,164.0,56.0,113.0,121.0,53.0,177.0,23.0,52.0,159.0,131.0,214.0,17.0,16.0,89.0,51.0,31.0,112.0,63.0,109.0,46.0,66.0,105.0,88.0,135.0,81.0,11.0,51.0,101.0,101.0,43.0,63.0,23.0,99.0,145.0,57.0,133.0,21.0,31.0,23.0,3.0,141.0,3.0,11.0,131.0,109.0,65.0,113.0,11.0,103.0,203.0,13.0,31.0,45.0,11.0,201.0,75.0,26.0,116.0,10.0,95.0,3.0,3.0,56.0,63.0,85.0,91.0,25.0,53.0,203.0,179.0,123.0,11.0,21.0,245.0,155.0,7.0,121.0,207.0,21.0,61.0,153.0,75.0,123.0,125.0,179.0,25.0,61.0,11.0,89.0,214.0,81.0,113.0,149.0,127.0,138.0,29.0,51.0,41.0,53.0,240.0,101.0,211.0,120.0,121.0,53.0,187.0,43.0,61.0,115.0,83.0,48.0,181.0,157.0,243.0,36.0,115.0,11 ...

# %%
def categorical_feature(x):
    if x <= 60:
        return 'Beginner'
    elif x <=120:
        return 'Medium'
    elif x <= 180:
        return 'Intermediate'
    else:
        return 'Famous'

# %%
user_fame['fame_feature'] = user_fame['fame'].map(categorical_feature)
user_fame[['country','city','gender','fame', 'fame_feature']]
# Out:
#        country         city  gender   fame  fame_feature
# 4           US       Denver    male  123.0  Intermediate
# 13          US   Pittsfield    male   53.0      Beginner
# 22          US      Chicago    male   45.0      Beginner
# 28          US     Portland    male   45.0      Beginner
# 29      Canada    Vancouver    male   46.0      Beginner
# ...        ...          ...     ...    ...           ...
# 26978       UK         York    male  171.0  Intermediate
# 27004       US      Hoboken    male   13.0      Beginner
# 27010  Denmark   Copenhagen    male   21.0      Beginner
# 27012   France       Nantes    male  118.0        Medium
# 27020       US  Minneapolis  female   31.0      Beginner
#
# [4632 rows x 5 columns]

# %%
user_fame[user_fame['fame_feature']=='Famous']
# Out:
#            id                      city              state       country  \
# 57     227471                 Arlington              Texas            US
# 223     40108                 Bengaluru          Karnataka         India
# 430       815                   Seattle         Washington            US
# 437    106173                      Oslo               Oslo        Norway
# 450    413515  Al Madinah Al Munawwarah      Medina Region  Saudi Arabia
# ...       ...                       ...                ...           ...
# 26508  242815                  Waterloo            Ontario        Canada
# 26670  426866                   Seattle         Washington            US
# 26738  186125                 Vancouver   British Columbia        Canada
# 26876  122953                    Tromsø  Troms og Finnmark        Norway
# 26951   63010                   Calgary            Alberta        Canada
#
#       gender  profile_length  activitymonthlyduration  highagreement  \
# 57      male             1.0                     7.70            8.0
# 223     male             3.0                     5.43            0.0
# 430     male             1.0                     2.66           17.0
# 437     male             1.0                     8.35            0.0
# 450     male             4.0                     9.72           41.0
# ...      ...             ...                      ...            ...
# 26508   male             1.0                     5.01            2.0
# 26670   male             1.0                    10.72           32.0
# 26738   male             1.0                     7.82           32.0
# 26876   male             1.0                    11.96            1.0
# 26951   male             2.0                     7.66           44.0
#
#        lowagreement  views   fame  questions  answers  comments  edits  \
# 57              0.0   45.0  214.0        8.0      5.0       8.0   29.0
# 223             0.0   90.0  208.0        1.0      9.0       6.0   14.0
# 430             0.0   52.0  202.0        5.0      1.0       1.0   19.0
# 437             0.0   31.0  183.0        2.0     14.0       2.0    6.0
# 450             0.0   77.0  249.0       26.0      1.0      31.0   82.0
# ...             ...    ...    ...        ...      ...       ...    ...
# 26508           0.0   12.0  216.0        1.0      1.0       2.0    4.0
# 26670           1.0   21.0  184.0        3.0      8.0       9.0   21.0
# 26738           0.0   27.0  186.0        4.0     14.0      13.0   32.0
# 26876           0.0   32.0  203.0        2.0      6.0       2.0   12.0
# 26951           1.0   33.0  220.0        2.0      3.0       4.0    9.0
#
#        tokens fame_feature
# 57       17.0       Famous
# 223       7.0       Famous
# 430      16.0       Famous
# 437       6.0       Famous
# 450      19.0       Famous
# ...       ...          ...
# 26508     4.0       Famous
# 26670    10.0       Famous
# 26738     9.0       Famous
# 26876     7.0       Famous
# 26951    10.0       Famous
#
# [600 rows x 17 columns]

# %%
hist_categorical_fame = (user_fame['fame_feature']
 .value_counts()
 .reset_index()
 .rename(columns=({'index': 'fame', 'fame_feature': 'count'}))
)
fig = px.histogram(hist_categorical_fame, x='count', y='fame',
                      title='Histogram of Fame Feature',
                      color='fame',
                      color_discrete_sequence=['#007f5f', '#2b9348', '#55a630', '#80b918'])
fig.layout.template = 'plotly_dark'
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="eab3f243-826b-4ea9-a1a3-5f810b877577" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eab3f243-826b-4ea9-a1a3-5f810b877577")) {                    Plotly.newPlot(                        "eab3f243-826b-4ea9-a1a3-5f810b877577",                        [{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"fame=%{y}<br>sum of count=%{x}<extra></extra>","legendgroup":"Beginner","marker":{"color":"#007f5f","pattern":{"shape":""}},"name":"Beginner","offsetgroup":"Beginner","orientation":"h","showlegend":true,"x":[1814],"xaxis":"x","y":["Beginner"],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"fame=%{y}<br>sum of count=%{x}<extra></extra>","legendgroup":"Medium","marker":{"color":"#2b9348","pattern":{"shape":""}},"name":"Medium","offsetgroup":"Medium","orientation":"h","showlegend":true,"x":[1296],"xaxis":"x","y":["Medium"],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"fame=%{y}<br>sum of count=%{x}<extra></extra>","legendgroup":"Intermediate","marker":{"color":"#55a630","pattern":{"shape":""}},"name":"Intermediate","offsetgroup":"Intermediate","orientation":"h","showlegend":true,"x":[922],"xaxis":"x","y":["Intermediate"],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"fame=%{y}<br>sum of count=%{x}<extra></extra>","legendgroup":"Famous","marker":{"color":"#80b918","pattern":{"shape":""}},"name":"Famous","offsetgroup":"Famous","orientation":"h","showlegend":true,"x":[600],"xaxis":"x","y":["Famous"],"yaxis":"y","type":"histogram"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111 ...
